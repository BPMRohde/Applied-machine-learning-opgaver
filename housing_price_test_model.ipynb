# %% [markdown]
# ## Import libraries

# %%
import pandas as pd
import numpy as np

from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score

# %% [markdown]
# Storing the data in a dataframe

# %%
homes_sold = pd.read_csv(
    "dkhousingprices.csv",
    sep=",",
    na_values="\\N",
    dtype={
        "no_rooms": "float64",
        "sqm_price": "float64",
        "yield_on_mortgage_credit_bonds%": "float64",
        "dk_ann_infl_rate%": "float64"
    }
)

# %%
homes_sold.head()
# Out:
#   date,"quarter","house_id","house_type","sales_type","year_build","purchase_price","%_change_between_offer_and_purchase","no_rooms","sqm","sqm_price","address","zip_code","city","area","region","nom_interest_rate%","dk_ann_infl_rate%","yield_on_mortgage_credit_bonds%"
# 0  2024-10-26 00:00:00.000000000,219,0,"Villa","r...
# 1  2024-10-26 00:00:00.000000000,219,2,"Summerhou...
# 2  2024-10-26 00:00:00.000000000,219,1,"Farm","re...
# 3  2024-10-25 00:00:00.000000000,219,3,"Apartment...
# 4  2024-10-25 00:00:00.000000000,219,4,"Villa","r...

# %%
#Drop all rows with na in the sqm column
homes_sold = homes_sold.dropna(subset=["quarter","house_type", "sales_type", "year_build", "no_rooms", "sqm", "area", "nom_interest_rate%"])
homes_sold.head()
# Out:
#                             date  quarter  house_id   house_type  \
# 0  2024-10-26 00:00:00.000000000      219         0        Villa
# 1  2024-10-26 00:00:00.000000000      219         2  Summerhouse
# 2  2024-10-26 00:00:00.000000000      219         1         Farm
# 3  2024-10-25 00:00:00.000000000      219         3    Apartment
# 4  2024-10-25 00:00:00.000000000      219         4        Villa
#
#      sales_type  year_build  purchase_price  \
# 0  regular_sale        1974         4350000
# 1  regular_sale        1956          450000
# 2  regular_sale        1955         6600000
# 3   family_sale        1945         1495000
# 4  regular_sale        1967         3375000
#
#    %_change_between_offer_and_purchase  no_rooms    sqm  sqm_price  \
# 0                                    0       5.0  215.0  20232.559
# 1                                    0       3.0   36.0  12500.000
# 2                                    0       3.0  180.0  36666.668
# 3                                    0       2.0   64.0  23359.375
# 4                                    0       5.0  176.0  19176.137
#
#                       address  zip_code        city                area  \
# 0               Kildevangen 5      8382    Hinnerup  East & mid jutland
# 1                Lykkestien 2      4400  Kalundborg       Other islands
# 2               Sæderupvej 58      9260     Gistrup       North jutland
# 3  Tage-Hansens Gade 5, 1. tv      8000    Aarhus C  East & mid jutland
# 4          Chr.Winthers Vej 5      8600   Silkeborg  East & mid jutland
#
#     region  nom_interest_rate%  dk_ann_infl_rate%  \
# 0  Jutland                 3.1                NaN
# 1  Zealand                 3.1                NaN
# 2  Jutland                 3.1                NaN
# 3  Jutland                 3.1                NaN
# 4  Jutland                 3.1                NaN
#
#    yield_on_mortgage_credit_bonds%
# 0                              NaN
# 1                              NaN
# 2                              NaN
# 3                              NaN
# 4                              NaN

# %% [markdown]
# ### Make dummy variables

# %%
X = pd.get_dummies(homes_sold[["quarter","house_type", "sales_type", "year_build", "no_rooms", "sqm", "area", "nom_interest_rate%" ]])
y = homes_sold["purchase_price"]
X.shape, y.shape
X.head()
# Out:
#    quarter  year_build  no_rooms    sqm  nom_interest_rate%  \
# 0      219        1974       5.0  215.0                 3.1
# 1      219        1956       3.0   36.0                 3.1
# 2      219        1955       3.0  180.0                 3.1
# 3      219        1945       2.0   64.0                 3.1
# 4      219        1967       5.0  176.0                 3.1
#
#    house_type_Apartment  house_type_Farm  house_type_Summerhouse  \
# 0                 False            False                   False
# 1                 False            False                    True
# 2                 False             True                   False
# 3                  True            False                   False
# 4                 False            False                   False
#
#    house_type_Townhouse  house_type_Villa  ...  sales_type_other_sale  \
# 0                 False              True  ...                  False
# 1                 False             False  ...                  False
# 2                 False             False  ...                  False
# 3                 False             False  ...                  False
# 4                 False              True  ...                  False
#
#    sales_type_regular_sale  area_Bornholm  area_Capital, Copenhagen  \
# 0                     True          False                     False
# 1                     True          False                     False
# 2                     True          False                     False
# 3                    False          False                     False
# 4                     True          False                     False
#
#    area_East & mid jutland  area_Fyn & islands  area_North Zealand  \
# 0                     True               False               False
# 1                    False               False               False
# 2                    False               False               False
# 3                     True               False               False
# 4                     True               False               False
#
#    area_North jutland  area_Other islands  area_South jutland
# 0               False               False               False
# 1               False                True               False
# 2                True               False               False
# 3               False               False               False
# 4               False               False               False
#
# [5 rows x 23 columns]

# %% [markdown]
# Make the training and testing split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
# Create and fit the model
simple_model = LinearRegression()
simple_model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
#Evaluate the model
print("Score on training set: {:.3f}".format(simple_model.score(X_train, y_train)))
print("Score on test set: {:.3f}".format(simple_model.score(X_test, y_test)))
# Out:
# Score on training set: 0.338
# Score on test set: 0.333
